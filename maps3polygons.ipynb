# %%
import folium
import geopandas as gpd
from folium.plugins import MarkerCluster
import pandas as pd

# %%
zipfile = ("C:/Users/Utente/Desktop/vscode_work/map_november/mapnov_hydrobasins_africa_fao.zip")

# %%
waterbasin_df = gpd.read_file(zipfile)

# %%
waterbasin_df.head()
# Out:
#    SUB_BAS  TO_BAS  MAJ_BAS       SUB_NAME     MAJ_NAME  SUB_AREA  MAJ_AREA  \
# 0    90002    -888     7009         Borkou    Lake Chad   1179610   2461890
# 1    30003   30272     7003   White Nile 5         Nile     97222   3074955
# 2    90008    -888     7009         Dillia    Lake Chad    162385   2461890
# 3    30029   30297     7003  Lake Victoria         Nile     69200   3074955
# 4   100030    -888     7010     Lake Rukwa  Rift Valley      3443    638878
#
#    LEGEND                                           geometry
# 0       9  POLYGON ((15.52500 13.52083, 15.52917 13.52083...
# 1       3  MULTIPOLYGON (((32.24167 6.16250, 32.25000 6.1...
# 2       9  POLYGON ((12.02917 16.12083, 12.03333 16.12083...
# 3       3  POLYGON ((33.26667 0.37500, 33.26667 0.37083, ...
# 4      10  POLYGON ((31.95000 -7.55000, 31.95000 -7.55833...

# %%
waterbasin_df.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# to create a clipping bounding box https://stackoverflow.com/questions/9070752/getting-the-bounding-box-of-a-vector-of-points
# https://geopandas.org/en/stable/docs/reference/api/geopandas.clip.html
# North Africa ( Morocco, Algeria, Tunisia, Libya, Egypt, Sudan, and the Western Sahara)
# coords:
#
# north south east west bounding box points for north african countries according to google maps right click
# 37.54, 9.51
# 14.11, 13.13
# 18.04479, 38.48
# 21.39, -17.45
