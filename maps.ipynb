# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
#Define coordinates of where we want to center our map
brussels_coords = [50.8499966, 4.3499986]

#Create the map
my_map = folium.Map(location = brussels_coords, zoom_start = 4, tiles = 'https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png', attr='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>')

#Display the map
my_map

# var Stadia_AlidadeSmooth = L.tileLayer('https://tiles.stadiamaps.com/tiles/alidade_smooth/{z}/{x}/{y}{r}.png', {
# 	maxZoom: 20,
# 	attribution: '&copy; <a href="https://stadiamaps.com/">Stadia Maps</a>, &copy; <a href="https://openmaptiles.org/">OpenMapTiles</a> &copy; <a href="http://openstreetmap.org">OpenStreetMap</a> contributors'
# });
#http://leaflet-extras.github.io/leaflet-providers/preview/
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
wind_farm_name = [["Hornsea Project Two"],["Hornsea Project One"],["Moray East"],["Triton Knoll"],["Borssele 1&2"],["Borssele 3&4"],["East Anglia ONE"],["Walney Extension"],["London Array"],["Kriegers Flak"],["Gemini Wind Farm"],["Beatrice"],["Gode Wind (phases 1+2)"],["Gwynt y Môr"],["Race Bank"],["Greater Gabbard"],["Jiangsu Qidong H1+H2"],["Hohe See"],["Borkum Riffgrund 2"],["Horns Rev 3"],["Dudgeon"],["Veja Mate"],["Anholt"],["BARD Offshore 1"],["Global Tech I"],["Rampion"],["Binhai North H2"],["Merkur"],["West of Duddon Sands"],["Arkona"],["Windpark Fryslân [nl]"],["Norther Offshore Wind Farm"],["Walney(phases 1&2)"],["Galloper"],["Wikinger"],["Nordsee One"],["Thorntonbank(phases 1–3)"],["Sheringham Shoal"],["Borkum Riffgrund 1"],["Rentel"],["Amrumbank West"],["Thanet"]]
largest_wind_coords = [[53.91, 1.551806],[53.885, 1.791],[58.167081, -2.698519],[53.4, 0.9],[51.702778, 3.076111],[51.707, 2.912389],[52.248056, 2.506111],[54.088056, -3.738056],[51.643889, 1.553611],[55.016667, 12.933333],[54.036111, 5.963056],[58.13, -3.07],[54.066667, 7.033333],[53.45, -3.583333],[53.266667, 0.833333],[51.88, 1.94],[32.12, 122.16],[54.433333, 6.316667],[53.951944, 6.488056],[55.816667, 7.7],[53.248889, 1.39],[54.316944, 5.870833],[56.6, 11.21],[54.366667, 5.983333],[54.5, 6.358333],[50.666667, -0.1],[34.5, 120.333333],[54.033333, 6.55],[53.983889, -3.463889],[54.782, 14.121],[53, 5.266667],[51.527778, 3.031944],[54.043889, -3.521944],[51.88, 1.94],[54.833889, 14.068056],[53.966667, 6.8],[51.55, 2.933333],[53.116667, 1.133333],[53.966667, 6.55],[51.591, 2.944],[54.5, 7.8],[51.433333, 1.633333]]
capacity_mw = [[1386],[1218],[950],[857],[752],[731],[714],[659],[630],[605],[600],[588],[582],[576],[573],[504],[503],[497],[450],[407],[402],[402],[400],[400],[400],[400],[400],[396],[389],[385],[382],[370],[367],[353],[350],[332],[325],[315],[312],[308],[302],[300]]

list_wind_farms = []

# Python3 code here creating class
class wind_farms: 
    def __init__(self, name, coord, capacity): 
        self.name = name 
        self.coord = coord
        self.capacity = capacity

for (a, b, c) in zip (wind_farm_name, largest_wind_coords, capacity_mw):
    # print(a,b,c)
    list_wind_farms.append(wind_farms (a, b, c))

for obj in list_wind_farms:
    # print(obj.name, obj.coord, obj.capacity, sep= ' ')
    # Add markers to the map
    folium.CircleMarker(obj.coord, tooltip = "Name: {}  ".format(str(obj.name)), popup = "Capacity in MW: {} ".format(str(obj.capacity))).add_to(my_map)


    #TODO I would like use the string version of the object to make it prettier in the map, no special characters and use markdown further. but good for now. 


#Save the map

my_map.save("wind_farms.html")

my_map.save("wind_farms.png")

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
